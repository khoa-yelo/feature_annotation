# %%
import pandas as pd

# %%
path = "/oak/stanford/groups/horence/khoa/scratch/repos/feature_annotation/test_data/outs/blast_outs/split_0.blast_out.tsv"
path2 = "/oak/stanford/groups/horence/khoa/scratch/repos/feature_annotation/test_data/outs/blast_outs/split_1.blast_out.tsv"

df = pd.read_csv(path, sep="\t", header=None)
df2 = pd.read_csv(path2, sep="\t", header=None)

# %%
pd.concat([df, df2], axis=0)
# Out:
#                              0                                  1      2   3   \
# 0   TTTTGATAAAATATGCTGATATTAAGT      gi|2378387486|emb|OX375767.1|  100.0  24
# 1   TTTTGTTGAGAACCACCAGCAGAAGAA  gi|2725020961|ref|XM_064880546.1|  100.0  27
# 2   TTTTCTTGATCTCTTGCCAGATTCTGC       gi|1845947043|gb|CP047869.1|  100.0  25
# 3   TTTTCTTGATCTCTTGCCAGATTCTGC   gi|255725053|ref|XM_002547410.1|  100.0  25
# 4   TTTTGGTTTTTCATAATGCGAAAAGTC       gi|1845947048|gb|CP047874.1|  100.0  24
# ..                          ...                                ...    ...  ..
# 67  TTTTGTTCTACTTTTTGTCAAACTAAC       gi|1469258526|gb|CP032019.1|  100.0  27
# 68  TTTTGTTCTACTTTTTGTCAAACTAAC       gi|1307445967|gb|CP025158.1|  100.0  27
# 69  TTTTGTTCTACTTTTTGTCAAACTAAC       gi|2592617207|gb|CP128823.1|  100.0  27
# 70  TTTTGTTCTACTTTTTGTCAAACTAAC       gi|2530258973|gb|CP115798.1|  100.0  27
# 71  TTTTTTGCATCCCCTCCAATTGTTAAT       gi|1845947043|gb|CP047869.1|  100.0  24
#
# ...
